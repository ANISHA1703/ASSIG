# %% [markdown]
# <a href="https://colab.research.google.com/github/ANISHA1703/ASSIG/blob/main/de_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d={}
for i in range(97,123):
  d[chr(i)]=i
  print(d)
# Out:
# {'a': 97}
# {'a': 97, 'b': 98}
# {'a': 97, 'b': 98, 'c': 99}
# {'a': 97, 'b': 98, 'c': 99, 'd': 100}
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101}
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102}
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103}
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103, 'h': 104}
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103, 'h': 104, 'i': 105}
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103, 'h': 104, 'i': 105, 'j': 106}
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103, 'h': 104, 'i': 105, 'j': 106, 'k': 107}
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103, 'h': 104, 'i': 105, 'j': 106, 'k': 107, 'l': 108}
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103, 'h': 104, 'i': 105, 'j': 106, 'k': 107, 'l': 108, 'm': 109}
# ...
